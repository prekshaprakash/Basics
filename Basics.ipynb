# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt

# %%
import warnings
from warnings import filterwarnings
filterwarnings("ignore")

# %%
data=pd.read_csv("ML.csv")

# %%
data.head()
# Out:
#    Obs     y    x1     x2     x3   x4    x5   x6
# 0    1  4540  2140  20640  30250  205  1732   99
# 1    2  4315  2016  20280  30010  195  1697  100
# 2    3  4095  1905  19860  29780  184  1662   97
# 3    4  3650  1675  18980  29330  164  1598   97
# 4    5  3200  1474  18100  28960  144  1541   97

# %%
X=data.iloc[:,2:] #column split, (rowstart:rowstart,columnstart:coulmn end), by default hence dont write the location of row because we want all the rows
y=data['y']

# %%
X
# Out:
#       x1     x2     x3   x4    x5   x6
# 0   2140  20640  30250  205  1732   99
# 1   2016  20280  30010  195  1697  100
# 2   1905  19860  29780  184  1662   97
# 3   1675  18980  29330  164  1598   97
# 4   1474  18100  28960  144  1541   97
# 5   2239  20740  30083  216  1709   87
# 6   2120  20305  29831  206  1669   87
# 7   1990  19961  29604  196  1640   87
# 8   1702  18916  29088  171  1572   85
# 9   1487  18012  28675  149  1522   85
# 10  2107  20520  30120  195  1740  101
# 11  1973  20130  29920  190  1711  100
# 12  1864  19780  29720  180  1682  100
# 13  1674  19020  29370  161  1630  100
# 14  1440  18030  28940  139  1572  101
# 15  2165  20680  30160  208  1704   98
# 16  2048  20340  29960  199  1679   96
# 17  1916  19860  29710  187  1642   94
# 18  1658  18950  29250  164  1576   94
# 19  1489  18700  28890  145  1528   94
# 20  2062  20500  30190  193  1748  101
# 21  1929  20050  29960  183  1713  100
# 22  1815  19680  29770  173  1684  100
# ...

# %%
y
# Out:
# 0     4540
# 1     4315
# 2     4095
# 3     3650
# 4     3200
# 5     4833
# 6     4617
# 7     4340
# 8     3820
# 9     3368
# 10    4445
# 11    4188
# 12    3981
# 13    3622
# 14    3125
# 15    4560
# 16    4340
# 17    4115
# 18    3630
# 19    3210
# 20    4330
# 21    4119
# 22    3891
# 23    3467
# 24    3045
# 25    4411
# 26    4203
# 27    3968
# 28    3531
# 29    3074
# 30    4350
# 31    4128
# 32    3940
# 33    3480
# 34    3064
# 35    4402
# 36    4180
# 37    3973
# 38    3530
# 39    3080
# Name: y, dtype: int64

# %%
X_train, X_test,y_train, y_test = train_test_split(X,y,random_state=104,test_size=0.2)

# %%
data.describe()
# Out:
#              Obs            y           x1            x2           x3  \
# count  40.000000    40.000000    40.000000     40.000000     40.00000
# mean   20.500000  3904.000000  1809.925000  19494.600000  29605.77500
# std    11.690452   504.646004   251.950482    940.944419    466.21776
# min     1.000000  3045.000000  1388.000000  17780.000000  28675.00000
# 25%    10.750000  3517.500000  1607.750000  18880.000000  29302.50000
# 50%    20.500000  3977.000000  1849.500000  19765.000000  29745.00000
# 75%    30.250000  4332.500000  2023.750000  20286.250000  29960.00000
# max    40.000000  4833.000000  2239.000000  20740.000000  30250.00000
#
#                x4           x5          x6
# count   40.000000    40.000000   40.000000
# mean   174.500000  1651.900000   97.425000
# std     23.436767    68.895983    4.717059
# min    133.000000  1522.000000   85.000000
# 25%    155.250000  1592.500000   97.000000
# 50%    179.000000  1668.000000   99.000000
# ...

# %%
data.mean()
# Out:
# Obs       20.500
# y       3904.000
# x1      1809.925
# x2     19494.600
# x3     29605.775
# x4       174.500
# x5      1651.900
# x6        97.425
# dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()

# %%
pred = LR.fit(X_train,y_train)

# %%
#import numpy as np
#OUTLIER log transformation
#def handle_outlier(col):
    #data[col]=np.log1p(data[col]
#handle_outlier("x1")
#sns.distplot(data["x3"])
#plt.show()

# %%
sns.distplot(data["x3"])
plt.show()

# %%
import seaborn as sns

# %%
def handle_outlier(col):
    data[col]=np.log1p(data[col])
handle_outlier("x1")
